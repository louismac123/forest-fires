# %%
import PIL.Image
import facets_improc as ip
import numpy as np
import matplotlib.pyplot as plt

# %%
h = PIL.Image.open('river.png')
img = np.array(h, dtype=np.int64)

img = img[:, :, :3]
img[:, :, 2] = 0
img[:, :, 1] = 0
img[img[:, :, 0] > 210] = 0

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 h = PIL.Image.open('river.png')
#       2 img = np.array(h, dtype=np.int64)
#       4 img = img[:, :, :3]
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/abhi/forest-fires/image_processing/river.png'

# %%
W_0 = np.array([[1,1,1],
                [1,1,1],
                [1,1,1]]
              ) * 10

img_linear = ip.linear_filter(img, W_0, mode = "reflect")

for i in range(1):
    img_linear = ip.linear_filter(img_linear, W_0, mode = "reflect")


plt.imshow(img_linear)
